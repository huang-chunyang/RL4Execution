# %%
import aqdatac
aqdatac.login('huangchunyang', password='20020308hd')

# %%
aqdatac.current_session()
# Out:
# aqdatac: version 0.2.3
# current user: huangchunyang
# current session expires at: 2024-08-01 20:58:57

# %%
aqdatac.accessible_tables()
# Out:
# {'aindexcsi500weight': ['*'],
#  'aindexhs300closeweight': ['*'],
#  'aindexhs300freeweight': ['*'],
#  'ashareeodprices': ['2009-01-01, 2019-12-31'],
#  'cftick': ['2019-01-01,2019-07-01'],
#  'cfuturescalendar': ['*'],
#  'chinaetfpchredmlist': ['*'],
#  'chinaetfpchredmmembers': ['*'],
#  'csbar_1d': ['2009-01-01, 2019-12-31'],
#  'csbar_30m': ['2015-01-01, 2019-12-31'],
#  'csdate': ['*'],
#  'csinfo': ['*'],
#  'csord': ['2019-01-01,2019-07-01'],
#  'cstick': ['2019-01-01,2019-07-01'],
#  'cstra': ['2019-01-01,2019-07-01']}

# %%
df = aqdatac.get_data("csinfo",row_filter="producttype='a'")

# %%
df = df[df['status'] == 'active']

# %%
df
# Out:
#             sym  name producttype  status  listeddate delisteddate  \
# 0     000001.SZ  平安银行           a  active  1991-04-03         <NA>
# 1     000002.SZ   万科A           a  active  1991-01-29         <NA>
# 3     000004.SZ  国华网安           a  active  1990-12-01         <NA>
# 4     000005.SZ  ST星源           a  active  1990-12-10         <NA>
# 5     000006.SZ  深振业A           a  active  1992-04-27         <NA>
# ...         ...   ...         ...     ...         ...          ...
# 5353  688799.SH  华纳药厂           a  active  2021-07-13         <NA>
# 5354  688800.SH   瑞可达           a  active  2021-07-22         <NA>
# 5355  688819.SH  天能股份           a  active  2021-01-18         <NA>
# 5356  688981.SH  中芯国际           a  active  2020-07-16         <NA>
# 5357  689009.SH  九号公司           a  active  2020-10-29         <NA>
#
#       issue_price
# 0            40.0
# 1             1.0
# 3             1.0
# 4            10.0
# 5            10.0
# ...           ...
# 5353        30.82
# 5354        15.02
# 5355        41.79
# 5356        27.46
# 5357        18.94
#
# [5102 rows x 7 columns]

# %%
import pandas as pd
start_date_str, end_date_str = "2019-01-01", "2019-05-01"
start_date, end_date = pd.to_datetime(start_date_str), pd.to_datetime(end_date_str)
sym_list = df['sym'].tolist()
type(sym_list)
# Out:
# list

# %%
df_30m = aqdatac.get_data("csbar_30m", start_date, end_date, sym_list)
df_30m
# Out:
#                date             datetime        sym   open   high    low  \
# 0        2019-01-02  2019-01-02 10:00:00  000001.SZ   9.39   9.42   9.21
# 1        2019-01-02  2019-01-02 10:00:00  000002.SZ  23.83  24.09   23.7
# 2        2019-01-02  2019-01-02 10:00:00  000004.SZ  16.05  16.16  16.01
# 3        2019-01-02  2019-01-02 10:00:00  000005.SZ   2.69    2.7   2.67
# 4        2019-01-02  2019-01-02 10:00:00  000006.SZ   5.18   5.25   5.16
# ...             ...                  ...        ...    ...    ...    ...
# 2175893  2019-04-30  2019-04-30 15:00:00  603991.SH  20.47  20.82  20.38
# 2175894  2019-04-30  2019-04-30 15:00:00  603993.SH   4.19   4.22   4.19
# 2175895  2019-04-30  2019-04-30 15:00:00  603997.SH   9.57   9.69   9.51
# 2175896  2019-04-30  2019-04-30 15:00:00  603998.SH   10.0  10.04   9.88
# 2175897  2019-04-30  2019-04-30 15:00:00  603999.SH   6.05    6.1   6.01
#
#          close      volume      turnover  tradecount
# 0         9.25  16452721.0  152967867.27      6057.0
# 1        23.86   6148430.0  146920104.91      4885.0
# 2        16.01     38200.0      613862.0        63.0
# 3         2.69    737300.0     1978929.0       328.0
# 4         5.17   1730791.0     9006391.8       609.0
# ...        ...         ...           ...         ...
# 2175893  20.78    142300.0     2948507.0       161.0
# 2175894   4.21   9855604.0    41421156.2      2962.0
# 2175895   9.65    615050.0     5900441.0       620.0
# 2175896  10.01   2560850.0    25526888.5      1985.0
# 2175897   6.09    660308.0    4003091.64       331.0
#
# [2175898 rows x 10 columns]

# %%
df_30m_0 = df_30m[df_30m['datetime'].dt.time == pd.to_datetime('10:00:00').time()] 
print(len(df_30m_0))
# Out:
# 272004

# %%
df_30m_0_trade = df_30m_0[df_30m_0['volume']!=0]
print(len(df_30m_0_trade))
# Out:
# 272004

# %%
sym_list_top100 = df_30m_0_trade[['sym', 'turnover']].groupby('sym').mean().nlargest(100, 'turnover').index

# %%
sym_list_top100
# Out:
# Index(['600030.SH', '601318.SH', '000725.SZ', '300059.SZ', '000063.SZ',
#        '600519.SH', '600352.SH', '000651.SZ', '600776.SH', '000858.SZ',
#        '600604.SH', '300017.SZ', '601066.SH', '000723.SZ', '601688.SH',
#        '000977.SZ', '600536.SH', '600837.SH', '000333.SZ', '002230.SZ',
#        '600895.SH', '600570.SH', '002565.SZ', '600518.SH', '000002.SZ',
#        '600036.SH', '603000.SH', '000050.SZ', '600516.SH', '601108.SH',
#        '600309.SH', '600460.SH', '002456.SZ', '600446.SH', '002547.SZ',
#        '600050.SH', '601166.SH', '603799.SH', '601099.SH', '600887.SH',
#        '002600.SZ', '002157.SZ', '300136.SZ', '300498.SZ', '600048.SH',
#        '600572.SH', '600928.SH', '601319.SH', '603019.SH', '002415.SZ',
#        '002195.SZ', '000001.SZ', '600276.SH', '002027.SZ', '600218.SH',
#        '601398.SH', '600703.SH', '002958.SZ', '000100.SZ', '000735.SZ',
#        '000750.SZ', '000830.SZ', '601989.SH', '601186.SH', '600585.SH',
#        '601162.SH', '601615.SH', '600157.SH', '600031.SH', '600487.SH',
#        '601288.SH', '601668.SH', '601519.SH', '002405.SZ', '000070.SZ',
#        '600783.SH', '300033.SZ', '002460.SZ', '601336.SH', '000413.SZ',
#        '600635.SH', '600816.SH', '002252.SZ', '600775.SH', '601138.SH',
#        '000636.SZ', '603220.SH', '600104.SH', '002049.SZ', '002466.SZ',
#        '002797.SZ', '002733.SZ', '000563.SZ', '000066.SZ', '600624.SH',
#        '000776.SZ', '601211.SH', '002017.SZ', '601881.SH', '002458.SZ'],
#       dtype='string[pyarrow]', name='sym')

# %%
df_train = df_30m_0_trade[df_30m_0_trade['sym'].isin(sym_list_top100)]
df_train['date'] = pd.to_datetime(df_train['date'])
df_train
# Out:
# /tmp/ipykernel_2045/1660598010.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['date'] = pd.to_datetime(df_train['date'])
#               date             datetime        sym   open   high    low  \
# 0       2019-01-02  2019-01-02 10:00:00  000001.SZ   9.39   9.42   9.21
# 1       2019-01-02  2019-01-02 10:00:00  000002.SZ  23.83  24.09   23.7
# 36      2019-01-02  2019-01-02 10:00:00  000050.SZ   9.85   9.86   9.75
# 44      2019-01-02  2019-01-02 10:00:00  000063.SZ   19.6  19.94  19.51
# 46      2019-01-02  2019-01-02 10:00:00  000066.SZ   4.77   4.78   4.71
# ...            ...                  ...        ...    ...    ...    ...
# 2151327 2019-04-30  2019-04-30 10:00:00  601989.SH   5.53   5.64   5.51
# 2151335 2019-04-30  2019-04-30 10:00:00  603000.SH  21.13  22.05  21.13
# 2151352 2019-04-30  2019-04-30 10:00:00  603019.SH   41.0  41.68   41.0
# 2151456 2019-04-30  2019-04-30 10:00:00  603220.SH   27.6  28.37   27.4
# 2151692 2019-04-30  2019-04-30 10:00:00  603799.SH  27.76  29.47  27.76
#
#          close      volume      turnover  tradecount
# 0         9.25  16452721.0  152967867.27      6057.0
# 1        23.86   6148430.0  146920104.91      4885.0
# 36         9.8   1083793.0   10622069.47       977.0
# 44       19.88  18939827.0  374143044.79     14831.0
# 46        4.73   2553003.0   12105680.37      1048.0
# ...        ...         ...           ...         ...
# 2151327   5.61  28965235.0  162024072.89      8778.0
# 2151335   21.9   8479333.0  183934573.65      9985.0
# 2151352  41.67   3556192.0  147248362.98      5401.0
# 2151456  28.07   1536400.0    43026895.0      3327.0
# 2151692   29.0  22444533.0  636986498.62     28285.0
#
# [7760 rows x 10 columns]

# %%
df_train_sort = df_train.sort_values(by=['sym', 'date'])
df_train_sort
# Out:
#               date             datetime        sym   open   high    low  \
# 0       2019-01-02  2019-01-02 10:00:00  000001.SZ   9.39   9.42   9.21
# 27416   2019-01-03  2019-01-03 10:00:00  000001.SZ   9.18   9.28   9.15
# 54840   2019-01-04  2019-01-04 10:00:00  000001.SZ   9.24   9.56   9.22
# 82264   2019-01-07  2019-01-07 10:00:00  000001.SZ   9.84   9.85   9.63
# 109680  2019-01-08  2019-01-08 10:00:00  000001.SZ   9.73   9.73   9.62
# ...            ...                  ...        ...    ...    ...    ...
# 2041115 2019-04-24  2019-04-24 10:00:00  603799.SH  36.78  37.57  36.78
# 2068804 2019-04-25  2019-04-25 10:00:00  603799.SH  37.13  37.13   36.3
# 2096459 2019-04-26  2019-04-26 10:00:00  603799.SH  35.56  35.89  34.63
# 2124099 2019-04-29  2019-04-29 10:00:00  603799.SH  31.86  31.86  30.84
# 2151692 2019-04-30  2019-04-30 10:00:00  603799.SH  27.76  29.47  27.76
#
#          close      volume      turnover  tradecount
# 0         9.25  16452721.0  152967867.27      6057.0
# 27416     9.25   9034788.0   83329838.94      4146.0
# 54840     9.49  33895094.0  318744473.46     12425.0
# 82264     9.66  34106436.0   332210830.8     11208.0
# 109680    9.67  12093436.0  116930219.24      5624.0
# ...        ...         ...           ...         ...
# 2041115  37.15   6898627.0  257097171.71     11205.0
# 2068804  36.59   6110773.0   223680932.8     10381.0
# 2096459   34.9   6308583.0  221647193.13     11959.0
# 2124099  30.84  10460200.0  326097809.34     16117.0
# 2151692   29.0  22444533.0  636986498.62     28285.0
#
# [7760 rows x 10 columns]

# %%
# df_train_sort.groupby('sym')['volume'].rolling(window=5, min_periods=1).mean().reset_index(level=0, drop=True)
df_train_sort['volume_prev_5d_avg'] = df_train_sort.groupby('sym')['volume'].apply(lambda x: x.shift(1).rolling(window=5, min_periods=1).mean()).reset_index(level=0, drop=True)

# %%
df_train_sort
# Out:
#               date             datetime        sym   open   high    low  \
# 0       2019-01-02  2019-01-02 10:00:00  000001.SZ   9.39   9.42   9.21
# 27416   2019-01-03  2019-01-03 10:00:00  000001.SZ   9.18   9.28   9.15
# 54840   2019-01-04  2019-01-04 10:00:00  000001.SZ   9.24   9.56   9.22
# 82264   2019-01-07  2019-01-07 10:00:00  000001.SZ   9.84   9.85   9.63
# 109680  2019-01-08  2019-01-08 10:00:00  000001.SZ   9.73   9.73   9.62
# ...            ...                  ...        ...    ...    ...    ...
# 2041115 2019-04-24  2019-04-24 10:00:00  603799.SH  36.78  37.57  36.78
# 2068804 2019-04-25  2019-04-25 10:00:00  603799.SH  37.13  37.13   36.3
# 2096459 2019-04-26  2019-04-26 10:00:00  603799.SH  35.56  35.89  34.63
# 2124099 2019-04-29  2019-04-29 10:00:00  603799.SH  31.86  31.86  30.84
# 2151692 2019-04-30  2019-04-30 10:00:00  603799.SH  27.76  29.47  27.76
#
#          close      volume      turnover  tradecount  volume_prev_5d_avg
# 0         9.25  16452721.0  152967867.27      6057.0                 NaN
# 27416     9.25   9034788.0   83329838.94      4146.0         16452721.00
# 54840     9.49  33895094.0  318744473.46     12425.0         12743754.50
# 82264     9.66  34106436.0   332210830.8     11208.0         19794201.00
# 109680    9.67  12093436.0  116930219.24      5624.0         23372259.75
# ...        ...         ...           ...         ...                 ...
# 2041115  37.15   6898627.0  257097171.71     11205.0         20766249.40
# 2068804  36.59   6110773.0   223680932.8     10381.0         18082770.20
# 2096459   34.9   6308583.0  221647193.13     11959.0         13979555.80
# 2124099  30.84  10460200.0  326097809.34     16117.0         12552099.20
# 2151692   29.0  22444533.0  636986498.62     28285.0          7996763.20
#
# [7760 rows x 11 columns]

# %%
df_train_sort_dropna = df_train_sort.dropna()
print(len(df_train_sort_dropna))
# Out:
# 7660

# %%
df_train_sort_dropna[['date', 'sym', 'volume', 'volume_prev_5d_avg']].reset_index(drop=True).to_csv('./train_set.csv')

# %%
volume = df_train_sort_dropna['volume']
volume_prev_5d_avg = df_train_sort_dropna['volume_prev_5d_avg']
delta_volume = (volume_prev_5d_avg - volume) / volume
delta_volume_percent = round(delta_volume * 100, 2)

# %%
df_train_sort_dropna.iloc[delta_volume_percent.argmax()-5: delta_volume_percent.argmax()+2]
# Out:
#              date             datetime        sym   open   high    low  close  \
# 799457 2019-02-19  2019-02-19 10:00:00  600604.SH    7.9    8.0   7.75   7.93
# 827004 2019-02-20  2019-02-20 10:00:00  600604.SH    8.2   8.29    8.1   8.16
# 854525 2019-02-21  2019-02-21 10:00:00  600604.SH   8.17   8.46   8.12   8.28
# 882078 2019-02-22  2019-02-22 10:00:00  600604.SH   8.59    9.6   8.55   9.59
# 909642 2019-02-25  2019-02-25 10:00:00  600604.SH  10.56  10.56  10.56  10.56
# 937177 2019-02-26  2019-02-26 10:00:00  600604.SH  11.62  11.62  11.62  11.62
# 964709 2019-02-27  2019-02-27 10:00:00  600604.SH   12.0  12.78   11.8  12.78
#
#              volume       turnover  tradecount  volume_prev_5d_avg
# 799457   29293168.0   230401869.87     14787.0          29001934.2
# 827004   27479408.0   224867109.55     15119.0          31488669.0
# 854525   33891825.0   282326229.57     16074.0          33946226.4
# 882078  130092249.0  1209475047.76     38875.0          28960526.6
# 909642    2337211.0    24680948.16       957.0          50080200.8
# 937177    1520124.0    17663840.88       716.0          44618772.2
# 964709  106442538.0  1324485709.45     45605.0          39064163.4

# %%
from matplotlib import pyplot as plt
sort = delta_volume_percent < 500
print('raw: ', len(delta_volume_percent), 'sorted: ', len(delta_volume_percent[sort]))
plt.hist(delta_volume_percent[sort], bins=100)
plt.show()
# Out:
# raw:  7660 sorted:  7632
